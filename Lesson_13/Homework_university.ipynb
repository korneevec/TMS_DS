# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go

train_df = pd.read_csv("files/timesData.csv")

# %%
train_df.head(20)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# ...

# %%
train_df.describe()
# Out:
#           teaching     research    citations  student_staff_ratio         year
# count  2603.000000  2603.000000  2603.000000          2544.000000  2603.000000
# mean     37.801498    35.910257    60.921629            18.445283  2014.075682
# std      17.604218    21.254805    23.073219            11.458698     1.685733
# min       9.900000     2.900000     1.200000             0.600000  2011.000000
# 25%      24.700000    19.600000    45.500000            11.975000  2013.000000
# 50%      33.900000    30.500000    62.500000            16.100000  2014.000000
# 75%      46.400000    47.250000    79.050000            21.500000  2016.000000
# max      99.700000    99.400000   100.000000           162.600000  2016.000000

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              2603 non-null   object
#  1   university_name         2603 non-null   object
#  2   country                 2603 non-null   object
#  3   teaching                2603 non-null   float64
#  4   international           2603 non-null   object
#  5   research                2603 non-null   float64
#  6   citations               2603 non-null   float64
#  7   income                  2603 non-null   object
#  8   total_score             2603 non-null   object
#  9   num_students            2544 non-null   object
#  10  student_staff_ratio     2544 non-null   float64
#  11  international_students  2536 non-null   object
#  12  female_male_ratio       2370 non-null   object
#  13  year                    2603 non-null   int64
# ...

# %%
train_df["country"].unique()
# Out:
# array(['United States of America', 'United Kingdom', 'Switzerland',
#        'Canada', 'Hong Kong', 'Japan', 'South Korea', 'Singapore',
#        'Australia', 'China', 'France', 'Sweden', 'Germany',
#        'Republic of Ireland', 'Finland', 'Taiwan', 'South Africa',
#        'Turkey', 'Netherlands', 'Belgium', 'Denmark', 'Norway', 'Spain',
#        'New Zealand', 'Egypt', 'Austria', 'Israel', 'Brazil', 'Italy',
#        'Russian Federation', 'Greece', 'Iceland', 'Czech Republic',
#        'India', 'Poland', 'Iran', 'Portugal', 'Thailand', 'Chile',
#        'Estonia', 'Saudi Arabia', 'Mexico', 'Colombia', 'Macau',
#        'Morocco', 'Luxembourg', 'Unisted States of America', 'Cyprus',
#        'Unted Kingdom', 'Uganda', 'Malaysia', 'Lebanon', 'Romania',
#        'Slovenia', 'Pakistan', 'Hungary', 'United Arab Emirates',
#        'Belarus', 'Serbia', 'Slovakia', 'Bangladesh', 'Ghana', 'Nigeria',
#        'Indonesia', 'Jordan', 'Latvia', 'Kenya', 'Argentina', 'Qatar',
# ...

# %%
corrections = {
    "Unisted States of America" : "United States of America",
    "Unted Kingdom":"United Kingdom"}

train_df["country"].replace(corrections)
# Out:
# 0       United States of America
# 1       United States of America
# 2       United States of America
# 3       United States of America
# 4       United States of America
#                   ...
# 2598                 South Korea
# 2599                      Turkey
# 2600                       Japan
# 2601                       Japan
# 2602                      Taiwan
# Name: country, Length: 2603, dtype: object

# %%
def ratio_to_int(ratio_str):
    if pd.isna(ratio_str):
        return None
    parts = ratio_str.split(' : ')
    if len(parts) == 2:
        return int(parts[0])
    return None

train_df['female_male_ratio_percent'] = train_df['female_male_ratio'].apply(ratio_to_int)

# %%
female_male_ratio_null = train_df["female_male_ratio_percent"].isnull().sum()
num_students = train_df['num_students'].isnull().sum()
student_staff_ratio = train_df["student_staff_ratio"].isnull().sum()


print(f"female_male_ratio_null null: {female_male_ratio_null}")
print(f"num_students null: {num_students}")
print(f"student_staff_ratio null: {student_staff_ratio}")
# Out:
# female_male_ratio_null null: 236
# num_students null: 59
# student_staff_ratio null: 59

# %%
train_df["female_male_ratio_percent"].mean()
# Out:
# 49.68398817068019

# %%
train_df["female_male_ratio_percent"] = train_df["female_male_ratio_percent"].fillna(train_df["female_male_ratio_percent"].median())

# %%
# train_df["female_male_ratio_percent"] = train_df["female_male_ratio_percent"].fillna(train_df.groupby('university_name')["female_male_ratio_percent"].median())
# train_df["female_male_ratio_percent"] = train_df["female_male_ratio_percent"].fillna(train_df.groupby('university_name')["female_male_ratio_percent"].mean())

# %%
# train_df["female_male_ratio_percent"] = train_df["female_male_ratio_percent"].fillna(0)
# train_df["female_male_ratio_percent"] = train_df["female_male_ratio_percent"].fillna(train_df.groupby('university_name')["female_male_ratio_percent"].median())

# %%
train_df.groupby('university_name')["female_male_ratio_percent"].median()
# Out:
# university_name
# AGH University of Science and Technology    52.0
# Aalborg University                          48.0
# Aalto University                            32.0
# Aarhus University                           54.0
# Aberystwyth University                      48.0
#                                             ...
# École Normale Supérieure                    46.0
# École Normale Supérieure de Lyon            49.0
# École Polytechnique                         18.0
# École Polytechnique Fédérale de Lausanne    27.0
# Örebro University                           61.0
# Name: female_male_ratio_percent, Length: 818, dtype: float64

# %% [markdown]
# не работают выше:

# %%
train_df.head(20)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# ...

# %%
female_male_ratio_null = train_df["female_male_ratio"].isnull().sum()
num_students = train_df['num_students'].isnull().sum()
student_staff_ratio = train_df["student_staff_ratio"].isnull().sum()


print(f"female_male_ratio_null null: {female_male_ratio_null}")
print(f"num_students null: {num_students}")
print(f"student_staff_ratio null: {student_staff_ratio}")
# Out:
# female_male_ratio_null null: 233
# num_students null: 59
# student_staff_ratio null: 59

# %%
train_df.groupby('university_name').size().reset_index(name='count')
# Out:
#                               university_name  count
# 0    AGH University of Science and Technology      1
# 1                          Aalborg University      5
# 2                            Aalto University      5
# 3                           Aarhus University      6
# 4                      Aberystwyth University      5
# ..                                        ...    ...
# 813                  École Normale Supérieure      6
# 814          École Normale Supérieure de Lyon      6
# 815                       École Polytechnique      6
# 816  École Polytechnique Fédérale de Lausanne      6
# 817                         Örebro University      1
#
# [818 rows x 2 columns]

# %%
train_df[train_df['university_name'] == 'AGH University of Science and Technology'].groupby('university_name').size().reset_index(name='count')
# Out:
#                             university_name  count
# 0  AGH University of Science and Technology      1

# %%
train_df[train_df['university_name'] == 'Harvard University'].groupby('university_name').size().reset_index(name='count')
# Out:
#       university_name  count
# 0  Harvard University      6

# %%
train_df[train_df['university_name'] == 'Örebro University']
# Out:
#      world_rank    university_name country  teaching international  research  \
# 2134    301-350  Örebro University  Sweden      18.3          39.4      10.4
#
#       citations income total_score num_students  student_staff_ratio  \
# 2134       87.8   29.8           -        8,788                 15.8
#
#      international_students female_male_ratio  year  female_male_ratio_percent
# 2134                     2%           61 : 39  2016                       61.0

# %%
train_df[train_df['university_name'] == 'Harvard University']
# Out:
#      world_rank     university_name                   country  teaching  \
# 0             1  Harvard University  United States of America      99.7
# 201           2  Harvard University  United States of America      95.8
# 605           4  Harvard University  United States of America      94.9
# 1003          2  Harvard University  United States of America      95.3
# 1403          2  Harvard University  United States of America      92.9
# 1808          6  Harvard University  United States of America      83.6
#
#      international  research  citations income total_score num_students  \
# 0             72.4      98.7       98.8   34.5        96.1       20,152
# 201           67.5      97.4       99.8   35.9        93.9       20,152
# 605           63.7      98.6       99.2   39.9        93.6       20,152
# 1003          66.2      98.5       99.1   40.6        93.9       20,152
# 1403          67.6      98.6       98.9   44.0        93.3       20,152
# ...
